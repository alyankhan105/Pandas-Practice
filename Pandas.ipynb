# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('DATA.csv')

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
df.tail()
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#           SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 523   SARAROGHA TEHSIL         813.0              98180         51479
# 524    SERWEKAI TEHSIL         398.0              54540         28695
# 525      TIARZA TEHSIL         734.0              45156         23649
# 526  TOI KHULLA TEHSIL         567.0              50413         27462
# 527        WANA TEHSIL        2315.0             153156         81342
#
#      FEMALE (RURAL)  TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  \
# 523           46694                    7             110.25  ...
# ...

# %%
df.shape   # Returns the number of rows and columns in the DataFrame
# Out:
# (528, 21)

# %%
df.info() # Provides a concise summary of the DataFrame, including the data types and non-null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
df.describe()  # Provides a statistical summary of the DataFrame
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
type(df['AREA (sq.km)'])
# Out:
# pandas.core.series.Series

# %%
df[['AREA (sq.km)', 'ALL SEXES (RURAL)']]  # Selecting multiple columns
# Out:
#      AREA (sq.km)  ALL SEXES (RURAL)
# 0          1729.0             619550
# 1          1500.0             540342
# 2          2536.0             361240
# 3          1295.0             382115
# 4          1818.0             452723
# ..            ...                ...
# 523         813.0              98180
# 524         398.0              54540
# 525         734.0              45156
# 526         567.0              50413
# 527        2315.0             153156
#
# [528 rows x 2 columns]

# %%
df['ALL SEXES (URBAN)'].shape
# Out:
# (528,)

# %%
df[['AREA (sq.km)', 'ALL SEXES (RURAL)']].shape  # Selecting multiple columns
# Out:
# (528, 2)

# %%
df.iloc[0]  # Accessing the first row of the DataFrame
# Out:
# PROVINCE                                     PUNJAB
# DIVISION                        BAHAWALPUR DIVISION
# DISTRICT                      BAHAWALNAGAR DISTRICT
# SUB DIVISION                    BAHAWALNAGAR TEHSIL
# AREA (sq.km)                                 1729.0
# ALL SEXES (RURAL)                            619550
# MALE (RURAL)                                 316864
# FEMALE (RURAL)                               302644
# TRANSGENDER (RURAL)                              42
# SEX RATIO (RURAL)                             104.7
# AVG HOUSEHOLD SIZE (RURAL)                      6.1
# POPULATION 1998 (RURAL)                      407768
# ANNUAL GROWTH RATE (RURAL)                     2.22
# ALL SEXES (URBAN)                            193840
# MALE (URBAN)                                  98391
# FEMALE (URBAN)                                95402
# TRANSGENDER (URBAN)                              47
# SEX RATIO (URBAN)                            103.13
# ...

# %%
df.iloc[0:3] # Accessing the first three rows of the DataFrame
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# 0                   42             104.70  ...                   407768
# 1                   54             102.73  ...                   395983
# 2                   44             102.30  ...                   250959
#
#    ANNUAL GROWTH RATE (RURAL)  ALL SEXES (URBAN)  MALE (URBAN)  \
# ...

# %%
df.iloc[0:3:2] # Accessing every second row from the first three rows
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 2        2536.0             361240        182655          178541
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# 0                   42              104.7  ...                   407768
# 2                   44              102.3  ...                   250959
#
#    ANNUAL GROWTH RATE (RURAL)  ALL SEXES (URBAN)  MALE (URBAN)  \
# 0                        2.22             193840         98391
# 2                        1.93              61528         31360
#
#    FEMALE (URBAN)  TRANSGENDER (URBAN)  SEX RATIO (URBAN)  \
# 0           95402                   47             103.13
# ...

# %%
df.iloc[:,[4,5,10]]  # Accessing specific columns by index
# Out:
#      AREA (sq.km)  ALL SEXES (RURAL)  AVG HOUSEHOLD SIZE (RURAL)
# 0          1729.0             619550                        6.10
# 1          1500.0             540342                        6.15
# 2          2536.0             361240                        6.32
# 3          1295.0             382115                        6.15
# 4          1818.0             452723                        6.29
# ..            ...                ...                         ...
# 523         813.0              98180                        7.57
# 524         398.0              54540                        7.20
# 525         734.0              45156                        7.99
# 526         567.0              50413                        9.34
# 527        2315.0             153156                       10.19
#
# [528 rows x 3 columns]

# %%
data=df['DIVISION']=='BAHAWALPUR DIVISION' # Filtering the DataFrame based on a condition
df[data]
# Out:
#    PROVINCE             DIVISION                 DISTRICT  \
# 0    PUNJAB  BAHAWALPUR DIVISION    BAHAWALNAGAR DISTRICT
# 1    PUNJAB  BAHAWALPUR DIVISION    BAHAWALNAGAR DISTRICT
# 2    PUNJAB  BAHAWALPUR DIVISION    BAHAWALNAGAR DISTRICT
# 3    PUNJAB  BAHAWALPUR DIVISION    BAHAWALNAGAR DISTRICT
# 4    PUNJAB  BAHAWALPUR DIVISION    BAHAWALNAGAR DISTRICT
# 5    PUNJAB  BAHAWALPUR DIVISION      BAHAWALPUR DISTRICT
# 6    PUNJAB  BAHAWALPUR DIVISION      BAHAWALPUR DISTRICT
# 7    PUNJAB  BAHAWALPUR DIVISION      BAHAWALPUR DISTRICT
# 8    PUNJAB  BAHAWALPUR DIVISION      BAHAWALPUR DISTRICT
# 9    PUNJAB  BAHAWALPUR DIVISION      BAHAWALPUR DISTRICT
# 10   PUNJAB  BAHAWALPUR DIVISION      BAHAWALPUR DISTRICT
# 11   PUNJAB  BAHAWALPUR DIVISION  RAHIM YAR KHAN DISTRICT
# 12   PUNJAB  BAHAWALPUR DIVISION  RAHIM YAR KHAN DISTRICT
# 13   PUNJAB  BAHAWALPUR DIVISION  RAHIM YAR KHAN DISTRICT
# 14   PUNJAB  BAHAWALPUR DIVISION  RAHIM YAR KHAN DISTRICT
#
# ...

# %%
df[data].shape  # Checking the shape of the filtered DataFrame
# Out:
# (15, 21)

# %%
def get_division_data(division_name):
    data = df['DIVISION'] == division_name
    return df[data].shape[0] # Returns the number of rows for the specified division

# %%
get_division_data('BAHAWALPUR DIVISION')  # Example usage of the function
# Out:
# 15

# %%
area=df['AREA (sq.km)']>1000    # Filtering the DataFrame for areas greater than 1000 sq.km
df[area]  # Displaying the filtered DataFrame
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 477       KPK          MALAKAND DIVISION         UPPER DIR DISTRICT
# 490  KPK/FATA  DERA ISMAIL KHAN DIVISION       FR D.I.KHAN DISTRICT
# 494  KPK/FATA          PESHAWAR DIVISION            KHYBER DISTRICT
# 507  KPK/FATA             BANNU DIVISION  NORTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...

# %%
df['AREA (sq.km)'].value_counts() # Counting the unique values in the 'AREA (sq.km)' column
# Out:
# AREA (sq.km)
# 419.0     4
# 0.0       4
# 762.0     3
# 250.0     3
# 418.0     3
#          ..
# 2964.0    1
# 5339.0    1
# 2012.0    1
# 1802.0    1
# 2315.0    1
# Name: count, Length: 466, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
#Pandas Plot
df['AREA (sq.km)'].head().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['PROVINCE'].value_counts().plot(kind='pie')  # Plotting the value counts of the 'PROVINCE' column
# Out:
# <Axes: ylabel='count'>

# %%
df['PROVINCE'].value_counts().plot(kind='hist')  # Plotting the value counts of the 'PROVINCE' column as a bar chart
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['PROVINCE'].value_counts().index # Getting the index of the value counts of the 'PROVINCE' column
# Out:
# Index(['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK', 'KPK/FATA'], dtype='object', name='PROVINCE')

# %%
df['PROVINCE'].value_counts().values # Getting the values of the value counts of the 'PROVINCE' column
# Out:
# array([143, 137, 131,  71,  46])

# %%
# Finding Missing values
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
df.groupby('DIVISION').size().sort_values()
# Out:
# DIVISION
# Badin Division                   5
# MARDAN DIVISION                  7
# SAHIWAL DIVISION                 7
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# DERA ISMAIL KHAN DIVISION       15
# HAZARA DIVISION                 15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# BAHAWALPUR DIVISION             15
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# Kalat Division                  18
# PESHAWAR DIVISION               18
# Mirpurkhas Division             18
# Sukkur Division                 18
# Zhob Division                   19
# Naseerabad Division             19
# GUJRANWALA DIVISION             20
# Larkana Division                21
# RAWALPINDI DIVISION             22
# Hyderabad Division              30
# Karachi Division                30
# MALAKAND DIVISION               33
# ...

# %%
df.groupby('DIVISION').size().sort_values()
# Out:
# DIVISION
# Badin Division                   5
# MARDAN DIVISION                  7
# SAHIWAL DIVISION                 7
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# DERA ISMAIL KHAN DIVISION       15
# HAZARA DIVISION                 15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# BAHAWALPUR DIVISION             15
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# Kalat Division                  18
# PESHAWAR DIVISION               18
# Mirpurkhas Division             18
# Sukkur Division                 18
# Zhob Division                   19
# Naseerabad Division             19
# GUJRANWALA DIVISION             20
# Larkana Division                21
# RAWALPINDI DIVISION             22
# Hyderabad Division              30
# Karachi Division                30
# MALAKAND DIVISION               33
# ...

# %%
#drop duplicates
df.drop_duplicates(inplace=True)  # Removes duplicate rows from the DataFrame
df
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...

# %%
#group by function
df.groupby('DIVISION').size().sort_values()  # Grouping by 'DIVISION' and counting the number of occurrences
# Out:
# DIVISION
# Badin Division                   5
# MARDAN DIVISION                  7
# SAHIWAL DIVISION                 7
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# DERA ISMAIL KHAN DIVISION       15
# HAZARA DIVISION                 15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# BAHAWALPUR DIVISION             15
# LAHORE DIVISION                 17
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# Kalat Division                  18
# PESHAWAR DIVISION               18
# Mirpurkhas Division             18
# Sukkur Division                 18
# Zhob Division                   19
# Naseerabad Division             19
# GUJRANWALA DIVISION             20
# Larkana Division                21
# RAWALPINDI DIVISION             22
# Hyderabad Division              30
# Karachi Division                30
# MALAKAND DIVISION               33
# ...

# %%
#null values
df.isnull().sum()  # Checking for null values in the DataFrame
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
df_1998=df['POPULATION 1998 (RURAL)'].sum()
df_2017=df['ALL SEXES (RURAL)'].sum()
print("THE SUM OF POPULATION OF 1998 IS",df_2017,"AND 2017 IS",df_2017)
# Out:
# THE SUM OF POPULATION OF 1998 IS 130034790 AND 2017 IS 130034790

# %%
df['SEX']=df['MALE (RURAL)']+df['FEMALE (RURAL)']+df['TRANSGENDER (RURAL)']

# %%
df['SEX'].mean()
# Out:
# np.float64(246278.01136363635)

# %%
#correlation
df.corr(numeric_only=True)  # Returns the correlation matrix of only numeric columns
# Out:
#                             AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# AREA (sq.km)                    1.000000           0.006860      0.010726
# ALL SEXES (RURAL)               0.006860           1.000000      0.999597
# MALE (RURAL)                    0.010726           0.999597      1.000000
# FEMALE (RURAL)                  0.002878           0.999574      0.998343
# TRANSGENDER (RURAL)             0.006880           0.873757      0.874089
# SEX RATIO (RURAL)               0.229985           0.159532      0.164477
# AVG HOUSEHOLD SIZE (RURAL)      0.081218           0.203010      0.201709
# POPULATION 1998 (RURAL)        -0.004228           0.962052      0.959554
# ANNUAL GROWTH RATE (RURAL)     -0.038601          -0.079973     -0.079388
# ALL SEXES (URBAN)              -0.126744           0.165477      0.165615
# MALE (URBAN)                   -0.126562           0.161580      0.161810
# FEMALE (URBAN)                 -0.126917           0.169629      0.169667
# ...

# %%
#rename column
df.rename(columns={'AREA (sq.km)': 'Area (sq.km)'}, inplace=True)  # Renaming a column

# %%
#dropna fun
df.dropna(inplace=True)  # Removes rows with any null values from the DataFrame

# %%
#fillna fun
df.fillna(0, inplace=True)  # Replaces all null values with 0 in the DataFrame

# %%
df.isnull().sum()  # Checking for null values in the DataFrame after filling
# Out:
# PROVINCE                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64
